# %%
import pandas as pd

# Especifica la ruta del archivo CSV
csv_path = "HAR Android Studio/sensor_data.csv"  # Reemplaza con la ruta correcta

# Lee el archivo CSV en un DataFrame de pandas
df = pd.read_csv(csv_path)

# Muestra las primeras filas del DataFrame para verificar que se haya cargado correctamente
df.head(15)
# Out:
#         Timestamp      AccX      AccY      AccZ     GyroX     GyroY     GyroZ  \
# 0   1712535943040 -0.040678  0.132203  9.829416 -0.000076 -0.000687  0.001374
# 1   1712535943085 -0.038285  0.138485  9.841082 -0.000076 -0.000916  0.001680
# 2   1712535943229 -0.029312  0.141177  9.832109 -0.000229 -0.000840  0.001680
# 3   1712535943427 -0.038285  0.136391  9.838689 -0.000076 -0.000611  0.001756
# 4   1712535943627 -0.037986  0.136690  9.838987 -0.000000 -0.000611  0.001680
# 5   1712535943827 -0.037687  0.135793  9.834202  0.000153 -0.000840  0.001756
# 6   1712535944027 -0.040379  0.136690  9.835997 -0.000076 -0.000687  0.001680
# 7   1712535944228 -0.043370  0.133699  9.833903 -0.000076 -0.000687  0.001680
# 8   1712535944430 -0.043071  0.138784  9.831510  0.000153 -0.000764  0.001833
# 9   1712535944632 -0.044865  0.141775  9.833903  0.000000 -0.000611  0.001909
# 10  1712535944835 -0.030508  0.140578  9.828220 -0.000153 -0.000687  0.001833
# ...

# %%
# Multiplica los valores de las columnas de acelerómetro por 1/9.81
df['AccX'] *= 1/9.81
df['AccY'] *= 1/9.81
df['AccZ'] *= 1/9.81

# Muestra las primeras filas del DataFrame con los valores modificados
print(df.head())
